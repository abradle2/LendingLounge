# %%
import os
import pickle
import json

# %%
import os
import pickle
import urllib2

# %%
with open('credentials.json') as credentials_file:
    credentials = json.load(credentials_file)
# Out:
# oDSdmoVr39mn67lAA7p/TZ4J56E=

# %%
api_key = credentials['lending_club']['api_key']
header = {'Authorization': api_key}
url = 'https://api.lendingclub.com/api/investor/v1/loans/listing'
req = urllib2.Request(url, None, header)
resp = urllib2.urlopen(req)

# %%
loans = resp.read()

# %%
loans
# Out:
# '{"asOfDate":"2015-01-18T19:29:54.170-08:00","loans":[{"id":39730913,"memberId":42554689,"loanAmount":2000.0,"fundedAmount":1425.0,"term":36,"intRate":14.31,"expDefaultRate":6.1,"serviceFeeRate":0.96,"installment":68.66,"grade":"C","subGrade":"C4","empLength":0,"homeOwnership":"OWN","annualInc":25000.0,"isIncV":"NOT_VERIFIED","acceptD":"2015-01-17T18:54:43.000-08:00","expD":"2015-01-31T19:03:19.000-08:00","listD":"2015-01-18T06:00:00.000-08:00","creditPullD":"2015-01-16T13:23:19.000-08:00","reviewStatusD":null,"reviewStatus":"NOT_APPROVED","desc":null,"purpose":"medical","addrZip":"956xx","addrState":"CA","investorCount":null,"ilsExpD":"2015-01-18T18:00:00.000-08:00","initialListStatus":"W","empTitle":"Photographer/Sales Consultant","accNowDelinq":2,"accOpenPast24Mths":0,"bcOpenToBuy":8058,"percentBcGt75":66.7,"bcUtil":54.7,"dti":23.0,"delinq2Yrs":2,"delinqAmnt":61349.0,"earliestCrLine":"1995-09-15T17:00:00.000-07:00","ficoRangeLow":675,"ficoRangeHigh":679,"inqLast6Mths":1,"mthsSinceLastDelinq":2,"mthsSinceLastRecord":null,"mthsSinceRecentInq":3,"mthsSinceRecentRevolDelinq":24,"mthsSinceRecentBc":34,"mortAcc":0,"openAcc":7,"pubRec":0,"totalBalExMort":77425,"revolBal":9766.0,"revolUtil":49.3,"totalBcLimit":17800,"totalAcc":9,"totalIlHighCreditLimit":12558,"numRevAccts":5,"mthsSinceRecentBcDlq":24,"pubRecBankruptcies":0,"numAcctsEver120Ppd":2,"chargeoffWithin12Mths":0,"collections12MthsExMed":0,"taxLiens":0,"mthsSinceLastMajorDerog":9,"numSats":5,"numTlOpPast12m":0,"moSinRcntTl":31,"totHiCredLim":93915,"totCurBal":77425,"avgCurBal":11061,"numBcTl":4,"numActvBcTl":2,"numBcSats":3,"pctTlNvrDlq":66,"numTl90gDpd24m":1,"numTl30dpd":2,"numTl120dpd2m":0,"numIlTl":1,"moSinOldIlAcct":31,"numActvRevTl":3,"moSinOldRevTlOp":99,"moSinRcntRevTlOp":34,"totalRevHiLim":19800,"numRevTlBalGt0":3,"numOpRevTl":4,"totCollAmt":0},{"id":39691798,"memberId":42515622,"loanAmount":7000.0,"fundedAmount":6275.0,"term":36,"intRate":13.66,"expDefaultRate":5.65,"serviceFeeRate":0.96,"installment":238.09,"grade":"C","subGrade":"C3","empLength":12,"homeOwnership":"RENT","annualInc":78500.0,"isIncV":"NOT_VERIFIED","acceptD":"2015-01-18T14:38:56.000-08:00","expD":"2015-02-01T14:46:10.000-08:00","listD":"2015-01-18T18:00:00.000-08:00","creditPullD":"2015-01-18T14:29:29.000-08:00","reviewStatusD":null,"reviewStatus":"NOT_APPROVED","desc":null,"purpose":"debt_consolidation","addrZip":"254xx","addrState":"WV","investorCount":null,"ilsExpD":"2015-01-18T18:00:00.000-08:00","initialListStatus":"F","empTitle":"Superintendent","accNowDelinq":0,"accOpenPast24Mths":5,"bcOpenToBuy":617,"percentBcGt75":66.7,"bcUtil":78.0,"dti":17.21,"delinq2Yrs":2,"delinqAmnt":0.0,"earliestCrLine":"2004-11-17T16:00:00.000-08:00","ficoRangeLow":670,"ficoRangeHigh":674,"inqLast6Mths":0,"mthsSinceLastDelinq":7,"mthsSinceLastRecord":null,"mthsSinceRecentInq":7,"mthsSinceRecentRevolDelinq":18,"mthsSinceRecentBc":1,"mortAcc":1,"openAcc":11,"pubRec":0,"totalBalExMort":64057,"revolBal":2183.0,"revolUtil":57.4,"totalBcLimit":2800,"totalAcc":38,"totalIlHighCreditLimit":68114,"numRevAccts":25,"mthsSinceRecentBcDlq":null,"pubRecBankruptcies":0,"numAcctsEver120Ppd":2,"chargeoffWithin12Mths":0,"collections12MthsExMed":0,"taxLiens":0,"mthsSinceLastMajorDerog":7,"numSats":11,"numTlOpPast12m":4,"moSinRcntTl":1,"totHiCredLim":71914,"totCurBal":64057,"avgCurBal":6406,"numBcTl":16,"numActvBcTl":2,"numBcSats":3,"pctTlNvrDlq":96,"numTl90gDpd24m":2,"numTl30dpd":0,"numTl120dpd2m":0,"numIlTl":11,"moSinOldIlAcct":122,"numActvRevTl":2,"moSinOldRevTlOp":120,"moSinRcntRevTlOp":1,"totalRevHiLim":3800,"numRevTlBalGt0":2,"numOpRevTl":5,"totCollAmt":0},{"id":39541598,"memberId":42365416,"loanAmount":6000.0,"fundedAmount":4275.0,"term":36,"intRate":16.49,"expDefaultRate":7.74,"serviceFeeRate":1.05,"installment":212.4,"grade":"D","subGrade":"D3","empLength":60,"homeOwnership":"RENT","annualInc":23000.0,"isIncV":"NOT_VERIFIED","acceptD":"2015-01-18T15:33:33.000-08:00","expD":"2015-02-01T15:41:31.000-08:00","listD":"2015-01-18T18 ...

# %%
json_data = json.loads(loans)

# %%
json_data['loans'][0]['addrState']
# Out:
# u'CA'
